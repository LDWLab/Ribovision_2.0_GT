# %% [markdown]
# # Update Nomenclature table through Python
#
# Check out [this](https://dev.mysql.com/doc/connector-python/en/connector-python-example-cursor-transaction.html) for tutorial on inserting data into tables.
#
# <span style="color:red">I'd recommend to turn special attention to their example of emp_no retrieval for the auto-incremental value of the last row.
# This will be a nice way to directly update the **Old_name** table with the appropriate *nomo_id* foreign key.</span>
#
# Code to obtain information for the Nomenclature table.
#
# The data is new_name of the protein and the occurence of the protein either in bacteria, archaea, or eukarya.
# If it is eukaya, whether it is available in mitochondria or chloroplast.

# %%
import csv
from collections import Counter
import numpy as np
import itertools 
import mysql.connector
import getpass

uname = input("User name: ")
pw = getpass.getpass("Password: ")
cnx = mysql.connector.connect(user=uname, password=pw, host='130.207.36.75', database='DESIRE')
cursor = cnx.cursor()


''' 
read the csv file and get the elements in each row.
make a list of the occurrences from each cell.
'''
def read_csv (csvfile):
	csvReader = csv.reader(csvfile, delimiter= ',')
	next(csvReader)
	occurList = []
	csvList=[]
	for row in csvReader:
		csvList.append(row)
		rowList = []
		count = 0
		for i in row[1]:
			if i.isalpha() == True:
				rowList.append(i)
		occurList.append(rowList)	
	return occurList,csvList
'''
return the occurList with the lists of occurrences from each cell.
return the csvList with the new names of all the proteins.
'''

def write_csv(occurList, csvList, cursor):
	nomenList=[]
	n=0
	for occurrences in occurList:
		i = 0
		while i < len(occurrences):
			query = ("INSERT INTO `DESIRE`.`Nomenclature`(`new_name`,`occurrence`) VALUES('"+csvList[n][0]+"','"+occurrences[i]+"')")
			cursor.execute(query)
            
			nomenList.append((csvList[n][0], occurrences[i]))
			i+=1
		n+=1
	cnx.commit()
	return 	nomenList

with open("../ban_table1.csv") as csvfile:	
	occurList,csvList = read_csv(csvfile)
	nomenList = write_csv(occurList, csvList, cursor)
	print(nomenList)

cursor.close()
cnx.close()
# Out:
# User name: vchivukula
# Password: ········
# ...

# %% [markdown]
# This code will help obtain data for both the Nomenclature and Old_name table. Pay attention to the query execution after each query to make sure the query is executed correctly, instead of the one cursor.execute(query1) at the end. Also, I used [this](https://dev.mysql.com/doc/connector-python/en/connector-python-example-cursor-transaction.html) link to get an idea to generate the nom_id using cursor.lastrowid, just the way they generated emp_no = cursor.lastrowid

# %%
import csv
from collections import Counter
import numpy as np
import itertools 
import mysql.connector
import getpass

'''
Generating a Nomenclature table and a Old_name table. The data is new_name of the protein 
and the occurrence of the protein either in bacteria, archaea, or eukarya. 
If it is eukarya, whether it is available in mitochondria or chloroplast.
The table can be directly exported to the database. The write_csv function checks for the occurrence and inputs
the corresponding old name for each of the occurrence. Please pay special attention 
to the code used to upload the output to the database. 
''' 


uname = input("User name: ")
pw = getpass.getpass("Password: ")
cnx = mysql.connector.connect(user=uname, password=pw, host='130.207.36.75', database='DESIRE')
cursor = cnx.cursor()

def read_csv (csvfile):
    ''' 
read the csv file and get the elements in each row.
make a list of the occurrences from each cell.
    '''
	csvReader = csv.reader(csvfile, delimiter= ',')
	next(csvReader)
	occurList = []
	csvList=[]
	for row in csvReader:
		csvList.append(row)
		rowList = []
		count = 0
		for i in row[1]:
			if i.isalpha() == True:
				rowList.append(i)
		occurList.append(rowList)	
	return occurList,csvList
'''
return the occurList with the lists of occurrences from each cell.
return the csvList with the new names of all the proteins.
'''
	
	
def write_csv(occurList, csvList, cursor):
	nomenList=[]
	n=0
	for occurrences in occurList:
		i = 0
		while i < len(occurrences):
			query = ("INSERT INTO `DESIRE`.`Nomenclature`(`new_name`,`occurrence`) VALUES('"+csvList[n][0]+"','"+occurrences[i]+"')")
			cursor.execute(query)
			j = cursor.lastrowid
			nomenList.append((csvList[n][0], occurrences[i]))
			if occurrences[i] == 'B':
				query1 = ("INSERT INTO `DESIRE`.`Old_name`(`nomo_id`,`old_name`, `yeast-human`) VALUES('"+str(j)+"','"+csvList[n][2]+"','"+occurrences[i]+"')")
				cursor.execute(query1)
			elif occurrences[i] == 'A':
				pass
			elif occurrences[i] == 'E':#This won't work (overwrites itself and gets executed further down)
				query1 = ("INSERT INTO `DESIRE`.`Old_name`(`nomo_id`,`old_name`, `yeast-human`) VALUES('"+str(j)+"','"+csvList[n][3]+"','"+'Y'+"')")
				cursor.execute(query1)
				query1 = ("INSERT INTO `DESIRE`.`Old_name`(`nomo_id`,`old_name`, `yeast-human`) VALUES('"+str(j)+"','"+csvList[n][4]+"','"+'H'+"')")
				cursor.execute(query1)
			elif occurrences[i] == 'm':
				query1 = ("INSERT INTO `DESIRE`.`Old_name`(`nomo_id`,`old_name`, `yeast-human`) VALUES('"+str(j)+"','"+csvList[n][5]+"','"+occurrences[i]+"')")
				cursor.execute(query1)
			elif occurrences[i] == 'c':
				query1 = ("INSERT INTO `DESIRE`.`Old_name`(`nomo_id`,`old_name`, `yeast-human`) VALUES('"+str(j)+"','"+csvList[n][6]+"','"+occurrences[i]+"')")
				cursor.execute(query1)
			i+=1
		n+=1
	cnx.commit()
	return 	nomenList


'''
Exporting the required output to the database table
'''


with open("../ban_table_1.csv") as csvfile:	
	occurList,csvList = read_csv(csvfile)
	#write_csv(occurList,csvList)
	nomenList = write_csv(occurList, csvList, cursor)
	#print(nomenList)
	
cursor.close()
cnx.close()

# %% [markdown]
# # Newest version
# Uses file ALL-BAN-NICK.csv which holds both LSU and SSU and has 7 columns:
# 1. Nick nomenclature
# 2. Ban nomenclature
# 3. Occurrence string
# 4. Bacterial old name
# 5. Yeast old name
# 6. Human old name
# 7. Archaeal old name

# %%
import csv
from collections import Counter
import numpy as np
import itertools 
import mysql.connector
import getpass

'''
Generating a Nomenclature table and a Old_name table. The data is new_name of the protein 
and the occurrence of the protein either in bacteria, archaea, or eukarya. 
If it is eukarya, whether it is available in mitochondria or chloroplast.
The table can be directly exported to the database. The write_csv function checks for the occurrence and inputs
the corresponding old name for each of the occurrence. Please pay special attention 
to the code used to upload the output to the database. 
''' 

uname = input("User name: ")
pw = getpass.getpass("Password: ")
cnx = mysql.connector.connect(user=uname, password=pw, host='130.207.36.75', database='ribovision3')
cursor = cnx.cursor()

def read_csv (csvfile):
	''' 
	Reads csv file with new names, occurences and old names,
	then returns a list of lists for the rows.
	'''
	csvReader = csv.reader(csvfile, delimiter= ',')
	next(csvReader)
	occurList = []
	csvList=[]
	for row in csvReader:
		csvList.append(row)
	return csvList

def execute_old_name_query(row, occurrence, lastrow_id):
	'''
	Checks the current occurence and executes queries for the Old_name table.
	'''
	if occurrence == 'B':
		if row[3]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[3]+"','"+occurrence+"')")
			cursor.execute(query)
	elif occurrence == 'A':
		if row[6]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[6]+"','"+occurrence+"')")
			cursor.execute(query)
	elif occurrence == 'E':
		if row[4]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[4]+"','Y')")
			cursor.execute(query)
		if row[5]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[5]+"','H')")
			cursor.execute(query)
	elif occurrence == 'm':
		if row[3]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[3]+"','B')")
			cursor.execute(query)
		if row[4]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[4]+"','mY')")
			cursor.execute(query)
		if row[5]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[5]+"','mH')")
			cursor.execute(query)
	elif occurrence == 'c':
		if row[3]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[3]+"','B')")
			cursor.execute(query)
		if row[4]:
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[4]+"','cY')")
			cursor.execute(query)
	else:
		raise ValueError('Occurence can only be B, A, E, m, or c!')
	return True

def upload_csv(csvList, cursor):
	lastrow_id=0
	for row in csvList:
		for occurrence in list(row[2]):
			if row[0][1] == 'S':
				query = ("INSERT INTO `ribovision3`.`Nomenclature`(`new_name`,`occurrence`,`MoleculeType`,`MoleculeGroup`) VALUES('"+row[0]+"','"+occurrence+"','prot','SSU')")
			elif row[0][1] == 'L':
				query = ("INSERT INTO `ribovision3`.`Nomenclature`(`new_name`,`occurrence`,`MoleculeType`,`MoleculeGroup`) VALUES('"+row[0]+"','"+occurrence+"','prot','LSU')")
			else:
				raise ValueError('Incorrect Molecule group! Can be only L or S: '+row[0])
			cursor.execute(query)
			lastrow_id = cursor.lastrowid
			execute_old_name_query(row, occurrence, lastrow_id)
			query = ("INSERT INTO `ribovision3`.`Old_name`(`nomo_id`,`old_name`,`N-B-Y-H-A`) VALUES('"+str(lastrow_id)+"','"+row[1]+"','BAN')")
			cursor.execute(query)
	cnx.commit()
	return True

with open("./ALL-BAN-NICK.csv") as csvfile:
	csvList = read_csv(csvfile)
	upload_csv(csvList, cursor)
	
cursor.close()
cnx.close()
