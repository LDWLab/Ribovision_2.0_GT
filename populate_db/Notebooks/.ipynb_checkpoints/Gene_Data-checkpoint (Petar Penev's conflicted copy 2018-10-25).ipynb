# %% [markdown]
# ### For Gene_Data
# [This](https://dataguide.nlm.nih.gov/eutilities/utilities.html) has been extremely useful, especially the part about efetch and the tables it links (which are very hard to find).
#
# We will need two separate Entrez query methods:
#     1. One for normally annotated species
#     2. Another for metagenomes of newly added species
# Both should return an xml which will be parsed differently according the !DOCTYPE tag (**Entrezgene-Set** or **GBSet**)
#
# The default setting for *retmax* is 20 which was limiting our geneID results. The maximum value that can be used is 100000. For higher numbers we need to use different approach, found [here](https://www.ncbi.nlm.nih.gov/books/NBK25499/). But I don't think it will be necessary since none of our species will have that many genes.
#
# Tags leading to the Gene ID:
#
#     <Entrezgene-Set>
#     <Entrezgene>
#       <Entrezgene_track-info>
#         <Gene-track>
#           <Gene-track_geneid>38094981</Gene-track_geneid>
#
# Tags leading to the gene name:
#
#     <Entrezgene_gene>
#         <Gene-ref>
#             <Gene-ref_locus>ytiA</Gene-ref_locus>
#
# Gene description and protein accession:
#
#     <Gene-commentary_products>
#         <Gene-commentary>
#           <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#           <Gene-commentary_label>uncharacterized protein YtiA</Gene-commentary_label>
#           <Gene-commentary_accession>YP_009518833</Gene-commentary_accession>
#           <Gene-commentary_version>1</Gene-commentary_version>
#
# There are several other tags that would be of interest, like chromosome, sequence interval from-to, strand direction.
#
# <span style="color:red">There are entries from multiple databases within &lt;Entrezgene&gt;, defining the same gene.</span> Ideally we are to use the reference ones &lt;Gene-ref&gt;, &lt;Prot-ref&gt;, &lt;Entrezgene_locus&gt;.

# %%
from Bio import Entrez
Entrez.email = "A.N.Other@example.com"  # Always tell NCBI who you are
handle = Entrez.esearch(db="gene", term="txid511145[Organism]",retmax=1)
record = Entrez.read(handle)
handle.close()
print(record)
handle = Entrez.efetch(db="gene", id=record['IdList'],rettype="xml")
genes=handle.read()

print(genes)
# Out:
# {'RetMax': '1', 'QueryTranslation': 'txid511145[Organism]', 'RetStart': '0', 'TranslationSet': [], 'Count': '4583', 'TranslationStack': [{'Count': '4583', 'Field': 'Organism', 'Explode': 'Y', 'Term': 'txid511145[Organism]'}, 'GROUP'], 'IdList': ['38094981']}
# <?xml version="1.0" ?>
# <!DOCTYPE Entrezgene-Set PUBLIC "-//NLM//DTD NCBI-Entrezgene, 21st January 2005//EN" "https://www.ncbi.nlm.nih.gov/data_specs/dtd/NCBI_Entrezgene.dtd">
# <Entrezgene-Set>
# <Entrezgene>
#   <Entrezgene_track-info>
#     <Gene-track>
#       <Gene-track_geneid>38094981</Gene-track_geneid>
#       <Gene-track_create-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2018</Date-std_year>
#               <Date-std_month>10</Date-std_month>
#               <Date-std_day>11</Date-std_day>
#               <Date-std_hour>19</Date-std_hour>
#               <Date-std_minute>5</Date-std_minute>
#               <Date-std_second>50</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_create-date>
#       <Gene-track_update-date>
#         <Date>
#           <Date_std>
#             <Date-std>
#               <Date-std_year>2018</Date-std_year>
#               <Date-std_month>10</Date-std_month>
#               <Date-std_day>11</Date-std_day>
#               <Date-std_hour>19</Date-std_hour>
#               <Date-std_minute>5</Date-std_minute>
#               <Date-std_second>50</Date-std_second>
#             </Date-std>
#           </Date_std>
#         </Date>
#       </Gene-track_update-date>
#     </Gene-track>
#   </Entrezgene_track-info>
#   <Entrezgene_type value="protein-coding">6</Entrezgene_type>
#   <Entrezgene_source>
#     <BioSource>
#       <BioSource_genome value="chromosome">21</BioSource_genome>
#       <BioSource_org>
#         <Org-ref>
#           <Org-ref_taxname>Escherichia coli str. K-12 substr. MG1655</Org-ref_taxname>
#           <Org-ref_db>
#             <Dbtag>
#               <Dbtag_db>taxon</Dbtag_db>
#               <Dbtag_tag>
#                 <Object-id>
#                   <Object-id_id>511145</Object-id_id>
#                 </Object-id>
#               </Dbtag_tag>
#             </Dbtag>
#           </Org-ref_db>
#           <Org-ref_orgname>
#             <OrgName>
#               <OrgName_name>
#                 <OrgName_name_binomial>
#                   <BinomialOrgName>
#                     <BinomialOrgName_genus>Escherichia</BinomialOrgName_genus>
#                     <BinomialOrgName_species>coli</BinomialOrgName_species>
#                   </BinomialOrgName>
#                 </OrgName_name_binomial>
#               </OrgName_name>
#               <OrgName_attrib>specified</OrgName_attrib>
#               <OrgName_mod>
#                 <OrgMod>
#                   <OrgMod_subtype value="strain">2</OrgMod_subtype>
#                   <OrgMod_subname>K-12</OrgMod_subname>
#                 </OrgMod>
#                 <OrgMod>
#                   <OrgMod_subtype value="substrain">3</OrgMod_subtype>
#                   <OrgMod_subname>MG1655</OrgMod_subname>
#                 </OrgMod>
#               </OrgName_mod>
#               <OrgName_lineage>Bacteria; Proteobacteria; Gammaproteobacteria; Enterobacterales; Enterobacteriaceae; Escherichia</OrgName_lineage>
#               <OrgName_gcode>11</OrgName_gcode>
#               <OrgName_div>BCT</OrgName_div>
#             </OrgName>
#           </Org-ref_orgname>
#         </Org-ref>
#       </BioSource_org>
#     </BioSource>
#   </Entrezgene_source>
#   <Entrezgene_gene>
#     <Gene-ref>
#       <Gene-ref_locus>ytiA</Gene-ref_locus>
#       <Gene-ref_db>
#         <Dbtag>
#           <Dbtag_db>ASAP</Dbtag_db>
#           <Dbtag_tag>
#             <Object-id>
#               <Object-id_str>ABE-0285711</Object-id_str>
#             </Object-id>
#           </Dbtag_tag>
#         </Dbtag>
#         <Dbtag>
#           <Dbtag_db>ECOCYC</Dbtag_db>
#           <Dbtag_tag>
#             <Object-id>
#               <Object-id_str>G0-16640</Object-id_str>
#             </Object-id>
#           </Dbtag_tag>
#         </Dbtag>
#       </Gene-ref_db>
#       <Gene-ref_syn>
#         <Gene-ref_syn_E>ECK4572</Gene-ref_syn_E>
#       </Gene-ref_syn>
#       <Gene-ref_locus-tag>b4715</Gene-ref_locus-tag>
#     </Gene-ref>
#   </Entrezgene_gene>
#   <Entrezgene_prot>
#     <Prot-ref>
#       <Prot-ref_desc>uncharacterized protein YtiA</Prot-ref_desc>
#     </Prot-ref>
#   </Entrezgene_prot>
#   <Entrezgene_gene-source>
#     <Gene-source>
#       <Gene-source_src>Entrez Genomes</Gene-source_src>
#       <Gene-source_src-int>556503834</Gene-source_src-int>
#       <Gene-source_src-str1>NC_000913</Gene-source_src-str1>
#       <Gene-source_src-str2>b4715</Gene-source_src-str2>
#     </Gene-source>
#   </Entrezgene_gene-source>
#   <Entrezgene_locus>
#     <Gene-commentary>
#       <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#       <Gene-commentary_accession>NC_000913</Gene-commentary_accession>
#       <Gene-commentary_version>3</Gene-commentary_version>
#       <Gene-commentary_seqs>
#         <Seq-loc>
#           <Seq-loc_int>
#             <Seq-interval>
#               <Seq-interval_from>4563667</Seq-interval_from>
#               <Seq-interval_to>4563924</Seq-interval_to>
#               <Seq-interval_strand>
#                 <Na-strand value="minus"/>
#               </Seq-interval_strand>
#               <Seq-interval_id>
#                 <Seq-id>
#                   <Seq-id_gi>556503834</Seq-id_gi>
#                 </Seq-id>
#               </Seq-interval_id>
#             </Seq-interval>
#           </Seq-loc_int>
#         </Seq-loc>
#       </Gene-commentary_seqs>
#       <Gene-commentary_products>
#         <Gene-commentary>
#           <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#           <Gene-commentary_label>uncharacterized protein YtiA</Gene-commentary_label>
#           <Gene-commentary_accession>YP_009518833</Gene-commentary_accession>
#           <Gene-commentary_version>1</Gene-commentary_version>
#           <Gene-commentary_refs>
#             <Pub>
#               <Pub_pmid>
#                 <PubMedId>9278503</PubMedId>
#               </Pub_pmid>
#             </Pub>
#             <Pub>
#               <Pub_pmid>
#                 <PubMedId>16397293</PubMedId>
#               </Pub_pmid>
#             </Pub>
#             <Pub>
#               <Pub_pmid>
#                 <PubMedId>16738553</PubMedId>
#               </Pub_pmid>
#             </Pub>
#           </Gene-commentary_refs>
#           <Gene-commentary_source>
#             <Other-source>
#               <Other-source_src>
#                 <Dbtag>
#                   <Dbtag_db>UniProtKB/Swiss-Prot</Dbtag_db>
#                   <Dbtag_tag>
#                     <Object-id>
#                       <Object-id_str>P0DN74</Object-id_str>
#                     </Object-id>
#                   </Dbtag_tag>
#                 </Dbtag>
#               </Other-source_src>
#             </Other-source>
#           </Gene-commentary_source>
#           <Gene-commentary_genomic-coords>
#             <Seq-loc>
#               <Seq-loc_int>
#                 <Seq-interval>
#                   <Seq-interval_from>4563667</Seq-interval_from>
#                   <Seq-interval_to>4563924</Seq-interval_to>
#                   <Seq-interval_strand>
#                     <Na-strand value="minus"/>
#                   </Seq-interval_strand>
#                   <Seq-interval_id>
#                     <Seq-id>
#                       <Seq-id_gi>556503834</Seq-id_gi>
#                     </Seq-id>
#                   </Seq-interval_id>
#                 </Seq-interval>
#               </Seq-loc_int>
#             </Seq-loc>
#           </Gene-commentary_genomic-coords>
#           <Gene-commentary_seqs>
#             <Seq-loc>
#               <Seq-loc_whole>
#                 <Seq-id>
#                   <Seq-id_gi>1489134520</Seq-id_gi>
#                 </Seq-id>
#               </Seq-loc_whole>
#             </Seq-loc>
#           </Gene-commentary_seqs>
#         </Gene-commentary>
#       </Gene-commentary_products>
#     </Gene-commentary>
#   </Entrezgene_locus>
#   <Entrezgene_comments>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>NCBI Reference Sequences (RefSeq)</Gene-commentary_heading>
#       <Gene-commentary_comment>
#         <Gene-commentary>
#           <Gene-commentary_type value="comment">254</Gene-commentary_type>
#           <Gene-commentary_heading>Genome Annotation</Gene-commentary_heading>
#           <Gene-commentary_products>
#             <Gene-commentary>
#               <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#               <Gene-commentary_heading>Reference assembly</Gene-commentary_heading>
#               <Gene-commentary_accession>NC_000913</Gene-commentary_accession>
#               <Gene-commentary_version>3</Gene-commentary_version>
#               <Gene-commentary_source>
#                 <Other-source>
#                   <Other-source_src>
#                     <Dbtag>
#                       <Dbtag_db>Nucleotide</Dbtag_db>
#                       <Dbtag_tag>
#                         <Object-id>
#                           <Object-id_id>556503834</Object-id_id>
#                         </Object-id>
#                       </Dbtag_tag>
#                     </Dbtag>
#                   </Other-source_src>
#                 </Other-source>
#               </Gene-commentary_source>
#               <Gene-commentary_seqs>
#                 <Seq-loc>
#                   <Seq-loc_int>
#                     <Seq-interval>
#                       <Seq-interval_from>4563667</Seq-interval_from>
#                       <Seq-interval_to>4563924</Seq-interval_to>
#                       <Seq-interval_strand>
#                         <Na-strand value="minus"/>
#                       </Seq-interval_strand>
#                       <Seq-interval_id>
#                         <Seq-id>
#                           <Seq-id_gi>556503834</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-interval_id>
#                     </Seq-interval>
#                   </Seq-loc_int>
#                 </Seq-loc>
#               </Gene-commentary_seqs>
#               <Gene-commentary_products>
#                 <Gene-commentary>
#                   <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#                   <Gene-commentary_heading>Product</Gene-commentary_heading>
#                   <Gene-commentary_accession>YP_009518833</Gene-commentary_accession>
#                   <Gene-commentary_version>1</Gene-commentary_version>
#                   <Gene-commentary_source>
#                     <Other-source>
#                       <Other-source_src>
#                         <Dbtag>
#                           <Dbtag_db>Protein</Dbtag_db>
#                           <Dbtag_tag>
#                             <Object-id>
#                               <Object-id_id>1489134520</Object-id_id>
#                             </Object-id>
#                           </Dbtag_tag>
#                         </Dbtag>
#                       </Other-source_src>
#                       <Other-source_anchor>YP_009518833</Other-source_anchor>
#                       <Other-source_post-text>uncharacterized protein YtiA [Escherichia coli str. K-12 substr. MG1655]</Other-source_post-text>
#                     </Other-source>
#                   </Gene-commentary_source>
#                   <Gene-commentary_seqs>
#                     <Seq-loc>
#                       <Seq-loc_whole>
#                         <Seq-id>
#                           <Seq-id_gi>1489134520</Seq-id_gi>
#                         </Seq-id>
#                       </Seq-loc_whole>
#                     </Seq-loc>
#                   </Gene-commentary_seqs>
#                   <Gene-commentary_comment>
#                     <Gene-commentary>
#                       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#                       <Gene-commentary_label>RefSeq Status</Gene-commentary_label>
#                       <Gene-commentary_text>PROVISIONAL</Gene-commentary_text>
#                     </Gene-commentary>
#                   </Gene-commentary_comment>
#                 </Gene-commentary>
#               </Gene-commentary_products>
#             </Gene-commentary>
#           </Gene-commentary_products>
#         </Gene-commentary>
#       </Gene-commentary_comment>
#     </Gene-commentary>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>Related Sequences</Gene-commentary_heading>
#       <Gene-commentary_products>
#         <Gene-commentary>
#           <Gene-commentary_type value="genomic">1</Gene-commentary_type>
#           <Gene-commentary_heading>Genomic</Gene-commentary_heading>
#           <Gene-commentary_accession>U00096</Gene-commentary_accession>
#           <Gene-commentary_version>3</Gene-commentary_version>
#           <Gene-commentary_source>
#             <Other-source>
#               <Other-source_src>
#                 <Dbtag>
#                   <Dbtag_db>Nucleotide</Dbtag_db>
#                   <Dbtag_tag>
#                     <Object-id>
#                       <Object-id_id>545778205</Object-id_id>
#                     </Object-id>
#                   </Dbtag_tag>
#                 </Dbtag>
#               </Other-source_src>
#               <Other-source_anchor>U00096</Other-source_anchor>
#             </Other-source>
#           </Gene-commentary_source>
#           <Gene-commentary_seqs>
#             <Seq-loc>
#               <Seq-loc_whole>
#                 <Seq-id>
#                   <Seq-id_gi>545778205</Seq-id_gi>
#                 </Seq-id>
#               </Seq-loc_whole>
#             </Seq-loc>
#           </Gene-commentary_seqs>
#           <Gene-commentary_products>
#             <Gene-commentary>
#               <Gene-commentary_type value="peptide">8</Gene-commentary_type>
#               <Gene-commentary_accession>AYC08261</Gene-commentary_accession>
#               <Gene-commentary_version>1</Gene-commentary_version>
#               <Gene-commentary_source>
#                 <Other-source>
#                   <Other-source_src>
#                     <Dbtag>
#                       <Dbtag_db>Protein</Dbtag_db>
#                       <Dbtag_tag>
#                         <Object-id>
#                           <Object-id_id>1481898099</Object-id_id>
#                         </Object-id>
#                       </Dbtag_tag>
#                     </Dbtag>
#                   </Other-source_src>
#                   <Other-source_anchor>AYC08261</Other-source_anchor>
#                 </Other-source>
#               </Gene-commentary_source>
#               <Gene-commentary_seqs>
#                 <Seq-loc>
#                   <Seq-loc_whole>
#                     <Seq-id>
#                       <Seq-id_gi>1481898099</Seq-id_gi>
#                     </Seq-id>
#                   </Seq-loc_whole>
#                 </Seq-loc>
#               </Gene-commentary_seqs>
#             </Gene-commentary>
#           </Gene-commentary_products>
#         </Gene-commentary>
#       </Gene-commentary_products>
#     </Gene-commentary>
#     <Gene-commentary>
#       <Gene-commentary_type value="comment">254</Gene-commentary_type>
#       <Gene-commentary_heading>RefSeq Status</Gene-commentary_heading>
#       <Gene-commentary_label>PROVISIONAL</Gene-commentary_label>
#     </Gene-commentary>
#   </Entrezgene_comments>
#   <Entrezgene_unique-keys></Entrezgene_unique-keys>
#   <Entrezgene_xtra-iq>
#     <Xtra-Terms>
#       <Xtra-Terms_tag>NUCLEOTIDE</Xtra-Terms_tag>
#       <Xtra-Terms_value>545778205</Xtra-Terms_value>
#     </Xtra-Terms>
#     <Xtra-Terms>
#       <Xtra-Terms_tag>PROTEIN</Xtra-Terms_tag>
#       <Xtra-Terms_value>1481898099</Xtra-Terms_value>
#     </Xtra-Terms>
#   </Entrezgene_xtra-iq>
#   <Entrezgene_non-unique-keys>
#     <Dbtag>
#       <Dbtag_db>ID</Dbtag_db>
#       <Dbtag_tag>
#         <Object-id>
#           <Object-id_id>556503834</Object-id_id>
#         </Object-id>
#       </Dbtag_tag>
#     </Dbtag>
#   </Entrezgene_non-unique-keys>
# </Entrezgene>
# </Entrezgene-Set>

# %% [markdown]
# ### For new species/metagenomes
# Proteins for species, determined from environmental samples are not present in the *gene* NCBI database. However, their protein sequences have been determined and exist in the *protein* database. We can use that to extract gi numbers, symbols, and descriptions.
#
#     <GBSeq_definition>Chain A, Uncharacterized protein</GBSeq_definition>
#     <GBSeq_primary-accession>5YEE_A</GBSeq_primary-accession>
#     <GBSeq_accession-version>5YEE_A</GBSeq_accession-version>
#     <GBSeq_other-seqids>
#       <GBSeqid>pdb|5YEE|A</GBSeqid>
#       <GBSeqid>gi|1482416786</GBSeqid>
#     </GBSeq_other-seqids>           <----- gi is more important than the tag in htis case

# %%
handle = Entrez.esearch(db="protein", term="txid1538547[Organism]")   #Lokiarchaeum
record = Entrez.read(handle)
handle.close()
print(record)
handle = Entrez.efetch(db="protein", id=record['IdList'],rettype="gp", retmode="xml")
genes=handle.read()

print(genes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a37db93731b> in <module>()
# ----> 1 handle = Entrez.esearch(db="protein", term="txid1538547[Organism]")   #Lokiarchaeum
#       2 record = Entrez.read(handle)
#       3 handle.close()
#       4 print(record)
#       5 handle = Entrez.efetch(db="protein", id=record['IdList'],rettype="gp", retmode="xml")
#
# NameError: name 'Entrez' is not defined

# %% [markdown]
# # Gene_Data table
# This table contains information regarding the GeneID, StrainID, the nomgd_ID(which is the nomenclature ID generated in the nomenclature table), gene symbol and gene description. It gets the strain ID from the species table and the gene information such as the gene ID, gene symbol and gene description from NCBI database.
#
# We need to build functions for cases where there are no hits for the query i.e., if we don't find any gene information for a particular strain ID.

# %%
#! /usr/bin/env python3

from Bio import Entrez
from xml.dom.minidom import parse, parseString
import xml.dom.minidom as minidom
import subprocess
import re
import mysql.connector
import getpass

uname = input("User name: ")
pw = getpass.getpass("Password: ")
cnx = mysql.connector.connect(user=uname, password=pw, host='130.207.36.75', database='DESIRE')
cursor = cnx.cursor()

def get_strainid():
	'''
	function to get a list of strain IDs from the TaxGroup table
	'''
	strainID_list = []
	cursor.execute("SELECT DESIRE.Species.strain_id FROM DESIRE.Species_TaxGroup\
				INNER JOIN DESIRE.TaxGroups ON DESIRE.Species_TaxGroup.taxgroup_id=DESIRE.TaxGroups.taxgroup_id\
				INNER JOIN DESIRE.Species ON DESIRE.Species_TaxGroup.strain_id=DESIRE.Species.strain_id\
				WHERE DESIRE.TaxGroups.groupName = 'Bacteria'")
	results = cursor.fetchall()
	for i in results:
		strainID_list.append(int(i[0]))
	#print(len(strainID_list))
	return strainID_list

def superkingdom_info(ID):
	'''
	function to get the superkingdoms for the strain IDs
	'''
	#print(ID)
	cursor.execute("SELECT DESIRE.TaxGroups.groupName FROM DESIRE.Species_TaxGroup\
		INNER JOIN DESIRE.TaxGroups ON DESIRE.Species_TaxGroup.taxgroup_id=DESIRE.TaxGroups.taxgroup_id\
		INNER JOIN DESIRE.Species ON DESIRE.Species_TaxGroup.strain_id=DESIRE.Species.strain_id\
		WHERE DESIRE.TaxGroups.groupLevel = 'superkingdom' AND DESIRE.Species.strain_id = '"+ID+"'")
	results = cursor.fetchall()
	superkingdom=(results[0][0])
	#print(superkingdom)
	return superkingdom

def nomid_oldname(domain_letter):
	'''
	function to get the nomo_id and old_name for the superkingdom obtained from superkingdom_info function
	'''
	cursor.execute("SELECT DESIRE.Old_name.nomo_id, DESIRE.Old_name.old_name FROM DESIRE.Old_name\
		INNER JOIN DESIRE.Nomenclature ON DESIRE.Old_name.nomo_id=DESIRE.Nomenclature.nom_id\
		WHERE DESIRE.Nomenclature.occurrence = '"+domain_letter+"' AND DESIRE.Old_name.N_B_Y_H_A = '"+domain_letter+"'")
	oldname = cursor.fetchall()
	# print(oldname)
	return oldname

def gene_info(taxid):
	'''
	function to get gene_id, gene_symbol, and gene_desc for the Gene_data table using the strain ID
	'''
	#print(taxid)
	geneinfo_output = subprocess.check_output("esearch -db gene -query 'txid"+taxid+"[Organism] ribosomal' | efetch -format tabular", shell=True)
	#print(geneinfo_output)
	gene_out = geneinfo_output.decode('utf-8')
	# print(gene_out)
	if re.match(".*https\:\/\/eutils\.st-va\.ncbi\.nlm\.nih\.gov\.*", gene_out):
		print("There is an error")
		pass
	elif re.match(".*https\:\/\/eutils\.be-md\.ncbi\.nlm\.nih\.gov\.*", gene_out):
		print("There is an error")
		pass
	else:
		# print(gene_out)
		gene_out = gene_out.split('\n')
		regex = re.compile('^tax_id\\tOrg_name\\tGeneID\\t.*')
		gene_out = [i for i in gene_out if not regex.match(i)] 
		regex = re.compile('.*NEWENTRY.*')
		gene_out = [i for i in gene_out if not regex.match(i)]
		# print(gene_out)
		genesym_desc=[]
		for item in gene_out[:-2]:
			gene_list=item.split('\t')
			if gene_list[7] == 'pseudo' or gene_list[7] == 'hypothetical protein':
				pass
			else:
				geneinfo = (gene_list[2], gene_list[5], gene_list[7]) # gene_id, gene_symbol, gene_desc
				# print(geneinfo)
				genesym_desc.append(geneinfo)
		#print(genesym_desc)
		return genesym_desc

def upload_data(name, desc, strainID):
	for i in name:
		old_name = i[1]
		nom_id=i[0]
		for j in desc:
			word = j[2]
			regexp = re.compile(r''+old_name+'$')
			regexp_RNA = re.compile(r'ribosomal RNA$')
			if regexp.search(word): 
				query = ("INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('"+str(j[0])+"','"+str(strainID)+"','"+str(i[0])+"','"+str(j[1])+"','"+str(j[2])+"')")
				# cursor.execute(query)
				print(query)
			if regexp_RNA.search(word):
				query = ("INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`, `GeneSymbol`, `GeneDescription`) VALUES('"+str(j[0])+"','"+str(strainID)+"','"+str(j[1])+"','"+str(j[2])+"')")
				# cursor.execute(query)
				print(query)


strainID_list=get_strainid()
	
for strainID in strainID_list:
	genesym_desc=gene_info(str(strainID))
	
	if len(genesym_desc) == 0:
		pass #change this - use another function to access protein db rather than gene db
	else:
		pass # use a function to upload last row increment, geneID
	
	# write a check if the list is empty

	superkingdom=superkingdom_info(str(strainID))
	nom_oldList = nomid_oldname(str(superkingdom[0]))
	upload_data(nom_oldList, genesym_desc, strainID)
#cnx.commit()
cursor.close()
cnx.close()
# Out:
# User name: vchivukula
# Password: ········
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('4
')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011947','197221','43','rplS','50S ribosomal protein L19')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011214','197221','44','rplT','50S ribosomal protein L20')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010290','197221','45','rplU','50S ribosomal protein L21')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010416','197221','46','rplV','50S ribosomal protein L22')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010423','197221','49','rplW','50S ribosomal protein L23')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010402','197221','52','rplX','50S ribosomal protein L24')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1012182','197221','55','rpl25','50S ribosomal protein L25')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010291','197221','56','rpmA','50S ribosomal protein L27')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010549','197221','57','rpmB','50S ribosomal protein L28')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010412','197221','58','rpmC','50S ribosomal protein L29')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010373','197221','64','rpmE','50S ribosomal protein L31')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1012564','197221','65','rpmF','50S ribosomal protein L32')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011568','197221','66','rpmG','50S ribosomal protein L33')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1012449','197221','67','rpmH','50S ribosomal protein L34')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011199','197221','68','rpmI','50S ribosomal protein L35')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010389','197221','69','rpmJ','50S ribosomal protein L36')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011583','197221','215','rps1','30S ribosomal protein S1')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010830','197221','216','rpsB','30S ribosomal protein S2')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010415','197221','219','rpsC','30S ribosomal protein S3')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010316','197221','222','rpsD','30S ribosomal protein S4')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010395','197221','225','rpsE','30S ribosomal protein S5')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011036','197221','228','rps6','30S ribosomal protein S6')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011047','197221','229','rps7','30S ribosomal protein S7')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010398','197221','232','rpsH','30S ribosomal protein S8')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010376','197221','235','rpsI','30S ribosomal protein S9')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011027','197221','238','rpsJ','30S ribosomal protein S10')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010387','197221','241','rps11','30S ribosomal protein S11')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011029','197221','244','rpsL','30S ribosomal protein S12')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010388','197221','247','rpsM','30S ribosomal protein S13')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010955','197221','250','rpsN','30S ribosomal protein S14')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011714','197221','253','rpsO','30S ribosomal protein S15')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010661','197221','256','rpsP','30S ribosomal protein S16')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010404','197221','257','rpsQ','30S ribosomal protein S17')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1011569','197221','260','rpsR','30S ribosomal protein S18')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010417','197221','261','rps19','30S ribosomal protein S19')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010716','197221','264','rpsT','30S ribosomal protein S20')
# INSERT INTO `DESIRE`.`Gene_data`(`GI`,`strain_ID`,`nomID`, `GeneSymbol`, `GeneDescription`) VALUES('1010659','197221','265','rpsU','30S ribosomal protein S21')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c8b2034f000c> in <module>()
#      98
#      99 for strainID in strainID_list:
# --> 100         genesym_desc=gene_info(str(strainID))
#     101
#     102         if len(genesym_desc) == 0:
#
# <ipython-input-1-c8b2034f000c> in gene_info(taxid)
#      51 	'''
#      52         #print(taxid)
# ---> 53         geneinfo_output = subprocess.check_output("esearch -db gene -query 'txid"+taxid+"[Organism] ribosomal' | efetch -format tabular", shell=True)
#      54         #print(geneinfo_output)
#      55         gene_out = geneinfo_output.decode('utf-8')
#
# ~/anaconda3/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# ~/anaconda3/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
# --> 405             stdout, stderr = process.communicate(input, timeout=timeout)
#     406         except TimeoutExpired:
#     407             process.kill()
#
# ~/anaconda3/lib/python3.6/subprocess.py in communicate(self, input, timeout)
#     828                 self._stdin_write(input)
#     829             elif self.stdout:
# --> 830                 stdout = self.stdout.read()
#     831                 self.stdout.close()
#     832             elif self.stderr:
#
# KeyboardInterrupt:
